# %%
ip.InteractiveTB.mode = "Verbose"  # "Verbose" "Minimal"

# %%
# %%micropython
import os

print(os.uname())
print(f"hello from {os.uname().sysname}")
# Out:
# (sysname='esp32', nodename='esp32', release='1.26.1', version='v1.26.1 on 2025-09-11', machine='Generic ESP32 module with ESP32')
# hello from esp32

# %%
for x in range(5):
    print(f"count {x}")
# Out:
# count 0
# count 1
# count 2
# count 3
# count 4

# %%
# %mpy --list ;
