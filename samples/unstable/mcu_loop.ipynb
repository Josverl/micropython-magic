# %%
# %mpy --list ;
# Out:
# VBox(children=(IntProgress(value=0, description='Updating', layout=Layout(width='100%'), max=2), HTML(value=''…

# %%
for d in mpy_magic["devices"]:
    comport = d["serialport"]
    print(f"Selecting device on {comport} (board: {d['board']})")
    # %mpy --select {comport}
    # %run -i detect_optional_features.ipynb
# Out:
# Selecting device on COM8 (board: RPI_PICO_W)
# MicroPython features available on rp2
# complex     = True
# native      = True
# viper       = True
# asm_thumb   = False
# asm_xtensa  = False
# asm_pio     = True
# vfs_vfsfat  = True
# vfs_vfslfs1 = False
# vfs_vfslfs2 = True
# vfs_vfsrom  = False
# vfs_vfsposix= False
# Selecting device on COM26 (board: SEEED_WIO_TERMINAL)
# MicroPython features available on samd
# complex     = False
# native      = True
# viper       = True
# asm_thumb   = False
# asm_xtensa  = False
# asm_pio     = False
# vfs_vfsfat  = True
# vfs_vfslfs1 = False
# vfs_vfslfs2 = True
# vfs_vfsrom  = False
# vfs_vfsposix= False
