# %%
# %run detect_optional_features.ipynb
# Out:
# MicroPython features available on esp32
# asm_thumb   = False
# asm_pio     = False
# native      = True
# complex     = True
# asm_xtensa  = False
# viper       = True

# %%
# %mpy --list ;

# %%
for d in mpy_magic["devices"]:
    comport = d["serialport"]
    print(f"Selecting device on {comport} (board: {d['board']})")
    # %mpy --select {comport}
    # %run -i detect_optional_features.ipynb
# Out:
# Selecting device on COM4 (board: ESP32_GENERIC)
# MicroPython features available on esp32
# asm_thumb   = False
# asm_pio     = False
# native      = True
# complex     = True
# asm_xtensa  = False
# viper       = True
# Selecting device on COM26 (board: SEEED_WIO_TERMINAL)
# MicroPython features available on samd
# asm_thumb   = False
# asm_pio     = False
# native      = True
# complex     = False
# asm_xtensa  = False
# viper       = True

# %%
print(features)
# Out:
# {}
