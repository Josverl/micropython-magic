# %% [markdown]
# ## MicroPython memory map visualizer
#
# The below class is used to visualize the memory map of MicroPython. It is based on the `micropython.memory_info(1)` output.
# It can be used to visualize the current usage of the memory before and after gc collection, or to visualize the difference between two memory maps.

# %%
from micropython_magic.memoryinfo import MemoryInfo

# %%
# issue soft reset before running
# %mpy --soft-reset
mem_lst = %mpy import micropython; micropython.mem_info(True)
# mem_lst
# Out:
# True
# stack: 596 out of 7936
# GC: total: 205568, used: 4464, free: 201104
#  No. of 1-blocks: 55, 2-blocks: 13, max blk sz: 64, max free sz: 12558
# GC memory layout; from 2000dd00:
# 00000000: h=MLhhhhBDhhBTTDBBBBBDhTh===BDBDB=BBBh=====BBBTB=BTB=BBBTB=TBTB=
# 00000400: Bh===TB=h===========B=h==hh============h========h===============
# 00000800: ===h============================================================
# 00000c00: ===h============================================================
# 00001000: ===h=h=hhBhhhhB..h..h..h=.....h=h=..............................
#        (195 lines all free)
# 00032000: ................................................

# %%
# create the memory map using the output, and display it
# map_1 = MemoryInfo(mem_lst.data, columns=1)
map_1 = MemoryInfo(mem_lst, cols=1)
map_1
# Out:
# Stack used:  0x0254 of Total: 0x1f00  pct free: 92.5%
# Memory used: 0x000_1170 of Total: 0x003_2300  free: 0x003_1190 pct free: 97.8%
# 1-Blocks:          55  2-Blocks:         13
# Max Block size:    64  Max Free size: 12558
# h=MLhhhhBDhhBTTDBBBBBDhTh===BDBDB=BBBh=====BBBTB=BTB=BBBTB=TBTB=
# Bh===TB=h===========B=h==hh============h========h===============
# ===h============================================================
# ===h============================================================
# ===h=h=hhBhhhhB..h..h..h=.....h=h=..............................
# ................................................

# %%
# default = 4 columns
map_1.columns = 2
map_1
# Out:
# Stack used:  0x0254 of Total: 0x1f00  pct free: 92.5%
# Memory used: 0x000_1170 of Total: 0x003_2300  free: 0x003_1190 pct free: 97.8%
# 1-Blocks:          55  2-Blocks:         13
# Max Block size:    64  Max Free size: 12558
# h=MLhhhhBDhhBTTDBBBBBDhTh===BDBDB=BBBh=====BBBTB=BTB=BBBTB=TBTB= Bh===TB=h===========B=h==hh============h========h===============
# ===h============================================================ ===h============================================================
# ===h=h=hhBhhhhB..h..h..h=.....h=h=.............................. ................................................

# %%
map_1.rainbow = True  # alternating colors for each block
map_1
# Out:
# Stack used:  0x0254 of Total: 0x1f00  pct free: 92.5%
# Memory used: 0x000_1170 of Total: 0x003_2300  free: 0x003_1190 pct free: 97.8%
# 1-Blocks:          55  2-Blocks:         13
# Max Block size:    64  Max Free size: 12558
# h=MLhhhhBDhhBTTDBBBBBDhTh===BDBDB=BBBh=====BBBTB=BTB=BBBTB=TBTB= Bh===TB=h===========B=h==hh============h========h===============
# ===h============================================================ ===h============================================================
# ===h=h=hhBhhhhB..h..h..h=.....h=h=.............................. ................................................

# %%
# consume some more memory
# %mpy print(help('modules'))
# %mpy import gc; gc.collect()

mem_lst = %mpy import micropython; micropython.mem_info(True)
map_2=MemoryInfo(mem_lst, cols=2 )
map_2.rainbow = True
map_2
# Out:
# __main__          asyncio/__init__  hashlib           rp2
# _asyncio          asyncio/core      heapq             select
# _boot             asyncio/event     io                socket
# _boot_fat         asyncio/funcs     json              ssl
# _onewire          asyncio/lock      lwip              struct
# _rp2              asyncio/stream    machine           sys
# _thread           binascii          math              time
# _webrepl          bluetooth         micropython       tls
# aioble/__init__   builtins          mip/__init__      uasyncio
# aioble/central    cmath             neopixel          uctypes
# aioble/client     collections       network           urequests
# aioble/core       cryptolib         ntptime           vfs
# aioble/device     deflate           onewire           webrepl
# aioble/l2cap      dht               os                webrepl_setup
# aioble/peripheral ds18x20           platform          websocket
# aioble/security   errno             random
# aioble/server     framebuf          re
# array             gc                requests/__init__
# Plus any modules on the filesystem
# None
# stack: 596 out of 7936
# GC: total: 205568, used: 4192, free: 201376
#  No. of 1-blocks: 38, 2-blocks: 13, max blk sz: 64, max free sz: 12451
# GC memory layout; from 2000dd00:
# 00000000: h=MLhhhh=DhhhhhDBBBBhDhBh===.DBDB=BBBh=====BBB.B=B.B=BBB.B=.B.B=
# 00000400: Bh===.B=h===========B=h==.h============h========h===============
# 00000800: ===h============================================================
# 00000c00: ===h============================================================
# 00001000: ===h=..........h=..h=...............................hh.B........
# 00001400: ................................................................
# 00001800: ...........h=...................................................
#        (193 lines all free)
# 00032000: ................................................
# Stack used:  0x0254 of Total: 0x1f00  pct free: 92.5%
# Memory used: 0x000_1060 of Total: 0x003_2300  free: 0x003_12a0 pct free: 98.0%
# 1-Blocks:          38  2-Blocks:         13
# Max Block size:    64  Max Free size: 12451
# h=MLhhhh=DhhhhhDBBBBhDhBh===.DBDB=BBBh=====BBB.B=B.B=BBB.B=.B.B= Bh===.B=h===========B=h==.h============h========h===============
# ===h============================================================ ===h============================================================
# ===h=..........h=..h=...............................hh.B........ ................................................................
# ...........h=................................................... ................................................

# %%
# %%micropython
# eat even more memory - with disabled gc
import gc

gc.disable()
foo = "Parrot"
try:
    for _ in range(15):
        foo = foo + foo
except MemoryError as e:
    print(e)
    pass
# Out:
# memory allocation failed, allocating 196609 bytes

# %%
# take anoter memory snapshot 
mem_lst = %mpy micropython.mem_info(True)
map_3=MemoryInfo(mem_lst)
map_3
# Out:
# stack: 596 out of 7936
# GC: total: 205568, used: 202048, free: 3520
#  No. of 1-blocks: 67, 2-blocks: 16, max blk sz: 6145, max free sz: 203
# GC memory layout; from 2000dd00:
# 00000000: h=MLhhhh=DhhhhhDBBBBhDhBh===hDBDB=BBBh=====BBBBB=BhB=BBBhB=hBSB=
# 00000400: Bh===SB=h===========B=h=SSh============h========h===============
# 00000800: ===h============================================================
# 00000c00: ===h============================================================
# 00001000: ===h=SSSh=hhhhhh=SSh=h===h===h======SSh=======SSSShThhhBB...h===
# 00001400: =h=====h============..h=h========h========================h====.
# 00001800: ...........h=h================================================h=
# 00001c00: ================================================================
# 00002000: ===============================h================================
# 00002400: ================================================================
# 00002800: ================================================================
# 00002c00: ================================h===============================
# 00003000: ================================================================
# 00003400: ================================================================
# 00003800: ================================================================
# 00003c00: ================================================================
# 00004000: ================================================================
# 00004400: =================================h==============================
# 00004800: ================================================================
# 00004c00: ================================================================
# 00005000: ================================================================
# 00005400: ================================================================
# 00005800: ================================================================
# 00005c00: ================================================================
# 00006000: ================================================================
# 00006400: ================================================================
# 00006800: ================================================================
# 00006c00: ================================================================
# 00007000: ================================================================
# 00007400: ==================================h=============================
# 00007800: ================================================================
# 00007c00: ================================================================
# 00008000: ================================================================
# 00008400: ================================================================
# 00008800: ================================================================
# 00008c00: ================================================================
# 00009000: ================================================================
# 00009400: ================================================================
# 00009800: ================================================================
# 00009c00: ================================================================
# 0000a000: ================================================================
# 0000a400: ================================================================
# 0000a800: ================================================================
# 0000ac00: ================================================================
# 0000b000: ================================================================
# 0000b400: ================================================================
# 0000b800: ================================================================
# 0000bc00: ================================================================
# 0000c000: ================================================================
# 0000c400: ================================================================
# 0000c800: ================================================================
# 0000cc00: ================================================================
# 0000d000: ================================================================
# 0000d400: ===================================h============================
# 0000d800: ================================================================
# 0000dc00: ================================================================
# 0000e000: ================================================================
# 0000e400: ================================================================
# 0000e800: ================================================================
# 0000ec00: ================================================================
# 0000f000: ================================================================
# 0000f400: ================================================================
# 0000f800: ================================================================
# 0000fc00: ================================================================
# 00010000: ================================================================
# 00010400: ================================================================
# 00010800: ================================================================
# 00010c00: ================================================================
# 00011000: ================================================================
# 00011400: ================================================================
# 00011800: ================================================================
# 00011c00: ================================================================
# 00012000: ================================================================
# 00012400: ================================================================
# 00012800: ================================================================
# 00012c00: ================================================================
# 00013000: ================================================================
# 00013400: ================================================================
# 00013800: ================================================================
# 00013c00: ================================================================
# 00014000: ================================================================
# 00014400: ================================================================
# 00014800: ================================================================
# 00014c00: ================================================================
# 00015000: ================================================================
# 00015400: ================================================================
# 00015800: ================================================================
# 00015c00: ================================================================
# 00016000: ================================================================
# 00016400: ================================================================
# 00016800: ================================================================
# 00016c00: ================================================================
# 00017000: ================================================================
# 00017400: ================================================================
# 00017800: ================================================================
# 00017c00: ================================================================
# 00018000: ================================================================
# 00018400: ================================================================
# 00018800: ================================================================
# 00018c00: ================================================================
# 00019000: ================================================================
# 00019400: ====================================h===========================
# 00019800: ================================================================
# 00019c00: ================================================================
# 0001a000: ================================================================
# 0001a400: ================================================================
# 0001a800: ================================================================
# 0001ac00: ================================================================
# 0001b000: ================================================================
# 0001b400: ================================================================
# 0001b800: ================================================================
# 0001bc00: ================================================================
# 0001c000: ================================================================
# 0001c400: ================================================================
# 0001c800: ================================================================
# 0001cc00: ================================================================
# 0001d000: ================================================================
# 0001d400: ================================================================
# 0001d800: ================================================================
# 0001dc00: ================================================================
# 0001e000: ================================================================
# 0001e400: ================================================================
# 0001e800: ================================================================
# 0001ec00: ================================================================
# 0001f000: ================================================================
# 0001f400: ================================================================
# 0001f800: ================================================================
# 0001fc00: ================================================================
# 00020000: ================================================================
# 00020400: ================================================================
# 00020800: ================================================================
# 00020c00: ================================================================
# 00021000: ================================================================
# 00021400: ================================================================
# 00021800: ================================================================
# 00021c00: ================================================================
# 00022000: ================================================================
# 00022400: ================================================================
# 00022800: ================================================================
# 00022c00: ================================================================
# 00023000: ================================================================
# 00023400: ================================================================
# 00023800: ================================================================
# 00023c00: ================================================================
# 00024000: ================================================================
# 00024400: ================================================================
# 00024800: ================================================================
# 00024c00: ================================================================
# 00025000: ================================================================
# 00025400: ================================================================
# 00025800: ================================================================
# 00025c00: ================================================================
# 00026000: ================================================================
# 00026400: ================================================================
# 00026800: ================================================================
# 00026c00: ================================================================
# 00027000: ================================================================
# 00027400: ================================================================
# 00027800: ================================================================
# 00027c00: ================================================================
# 00028000: ================================================================
# 00028400: ================================================================
# 00028800: ================================================================
# 00028c00: ================================================================
# 00029000: ================================================================
# 00029400: ================================================================
# 00029800: ================================================================
# 00029c00: ================================================================
# 0002a000: ================================================================
# 0002a400: ================================================================
# 0002a800: ================================================================
# 0002ac00: ================================================================
# 0002b000: ================================================================
# 0002b400: ================================================================
# 0002b800: ================================================================
# 0002bc00: ================================================================
# 0002c000: ================================================================
# 0002c400: ================================================================
# 0002c800: ================================================================
# 0002cc00: ================================================================
# 0002d000: ================================================================
# 0002d400: ================================================================
# 0002d800: ================================================================
# 0002dc00: ================================================================
# 0002e000: ================================================================
# 0002e400: ================================================================
# 0002e800: ================================================================
# 0002ec00: ================================================================
# 0002f000: ================================================================
# 0002f400: ================================================================
# 0002f800: ================================================================
# 0002fc00: ================================================================
# 00030000: ================================================================
# 00030400: ================================================================
# 00030800: ================================================================
# 00030c00: ================================================================
# 00031000: ================================================================
# 00031400: =====================================...........................
#        (2 lines all free)
# 00032000: ................................................
# Stack used:  0x0254 of Total: 0x1f00  pct free: 92.5%
# Memory used: 0x003_1540 of Total: 0x003_2300  free: 0x000_0dc0 pct free: 1.7%
# 1-Blocks:          67  2-Blocks:         16
# Max Block size:  6145  Max Free size:   203
# h=MLhhhh=DhhhhhDBBBBhDhBh===hDBDB=BBBh=====BBBBB=BhB=BBBhB=hBSB= Bh===SB=h===========B=h=SSh============h========h=============== ===h============================================================ ===h============================================================
# ===h=SSSh=hhhhhh=SSh=h===h===h======SSh=======SSSShThhhBB...h=== =h=====h============..h=h========h========================h====. ...........h=h================================================h= ================================================================
# ===============================h================================ ================================================================ ================================================================ ================================h===============================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ =================================h============================== ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ==================================h============================= ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ===================================h============================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ====================================h=========================== ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ =====================================........................... ................................................

# %%
map_3.rainbow = True
map_3
# Out:
# Stack used:  0x0254 of Total: 0x1f00  pct free: 92.5%
# Memory used: 0x003_1540 of Total: 0x003_2300  free: 0x000_0dc0 pct free: 1.7%
# 1-Blocks:          67  2-Blocks:         16
# Max Block size:  6145  Max Free size:   203
# h=MLhhhh=DhhhhhDBBBBhDhBh===hDBDB=BBBh=====BBBBB=BhB=BBBhB=hBSB= Bh===SB=h===========B=h=SSh============h========h=============== ===h============================================================ ===h============================================================
# ===h=SSSh=hhhhhh=SSh=h===h===h======SSh=======SSSShThhhBB...h=== =h=====h============..h=h========h========================h====. ...........h=h================================================h= ================================================================
# ===============================h================================ ================================================================ ================================================================ ================================h===============================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ =================================h============================== ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ==================================h============================= ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ===================================h============================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ====================================h=========================== ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ =====================================........................... ................................................

# %%
# compare snapshot 1 and 2 to see
#  - what remained the same = Black on Blue
#  - what was freed up = Green on Green ( can also be due to additional pages being reported)
#  - what was allocated = Yellow or White on Red

map_3 - map_1
# Out:
#  -->
# Stack used:  0x0254 of Total: 0x1f00  pct free: 92.5%
# Memory used: 0x003_1540 of Total: 0x003_2300  free: 0x000_0dc0 pct free: 1.7%
# 1-Blocks:          67  2-Blocks:         16
# Max Block size:  6145  Max Free size:   203
# h=MLhhhh=DhhhhhDBBBBhDhBh===hDBDB=BBBh=====BBBBB=BhB=BBBhB=hBSB= Bh===SB=h===========B=h=SSh============h========h=============== ===h============================================================ ===h============================================================
# ===h=SSSh=hhhhhh=SSh=h===h===h======SSh=======SSSShThhhBB...h=== =h=====h============..h=h========h========================h====. ...........h=h================================================h= ================================================================
# ===============================h================================ ================================================================ ================================================================ ================================h===============================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ =================================h============================== ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ==================================h============================= ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ===================================h============================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ====================================h=========================== ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ =====================================........................... ................................................

# %%
# now free up some memory and take another memory snapshot 
# %mpy import gc; gc.collect()
mem_lst = %mpy import micropython; micropython.mem_info(True)
map_4=MemoryInfo(mem_lst )
map_4.rainbow = True
map_4.show_free = True
map_4
# Out:
# stack: 596 out of 7936
# GC: total: 205568, used: 102816, free: 102752
#  No. of 1-blocks: 39, 2-blocks: 13, max blk sz: 6145, max free sz: 6147
# GC memory layout; from 2000dd00:
# 00000000: h=MLhhhh=DhhhhhDBBBBhDhBh===.DBDB=BBBh=====BBB.B=B.B=BBB.B=.B.B=
# 00000400: Bh===.B=h===========B=....h============h========h===============
# 00000800: ===h============================================================
# 00000c00: ===h============================================================
# 00001000: ===h=.......h=..h=...h===.............h=======..S........hh.....
# 00001400: .....................B..h========...............................
#        (95 lines all free)
# 00019400: ....................................h===========================
# 00019800: ================================================================
# 00019c00: ================================================================
# 0001a000: ================================================================
# 0001a400: ================================================================
# 0001a800: ================================================================
# 0001ac00: ================================================================
# 0001b000: ================================================================
# 0001b400: ================================================================
# 0001b800: ================================================================
# 0001bc00: ================================================================
# 0001c000: ================================================================
# 0001c400: ================================================================
# 0001c800: ================================================================
# 0001cc00: ================================================================
# 0001d000: ================================================================
# 0001d400: ================================================================
# 0001d800: ================================================================
# 0001dc00: ================================================================
# 0001e000: ================================================================
# 0001e400: ================================================================
# 0001e800: ================================================================
# 0001ec00: ================================================================
# 0001f000: ================================================================
# 0001f400: ================================================================
# 0001f800: ================================================================
# 0001fc00: ================================================================
# 00020000: ================================================================
# 00020400: ================================================================
# 00020800: ================================================================
# 00020c00: ================================================================
# 00021000: ================================================================
# 00021400: ================================================================
# 00021800: ================================================================
# 00021c00: ================================================================
# 00022000: ================================================================
# 00022400: ================================================================
# 00022800: ================================================================
# 00022c00: ================================================================
# 00023000: ================================================================
# 00023400: ================================================================
# 00023800: ================================================================
# 00023c00: ================================================================
# 00024000: ================================================================
# 00024400: ================================================================
# 00024800: ================================================================
# 00024c00: ================================================================
# 00025000: ================================================================
# 00025400: ================================================================
# 00025800: ================================================================
# 00025c00: ================================================================
# 00026000: ================================================================
# 00026400: ================================================================
# 00026800: ================================================================
# 00026c00: ================================================================
# 00027000: ================================================================
# 00027400: ================================================================
# 00027800: ================================================================
# 00027c00: ================================================================
# 00028000: ================================================================
# 00028400: ================================================================
# 00028800: ================================================================
# 00028c00: ================================================================
# 00029000: ================================================================
# 00029400: ================================================================
# 00029800: ================================================================
# 00029c00: ================================================================
# 0002a000: ================================================================
# 0002a400: ================================================================
# 0002a800: ================================================================
# 0002ac00: ================================================================
# 0002b000: ================================================================
# 0002b400: ================================================================
# 0002b800: ================================================================
# 0002bc00: ================================================================
# 0002c000: ================================================================
# 0002c400: ================================================================
# 0002c800: ================================================================
# 0002cc00: ================================================================
# 0002d000: ================================================================
# 0002d400: ================================================================
# 0002d800: ================================================================
# 0002dc00: ================================================================
# 0002e000: ================================================================
# 0002e400: ================================================================
# 0002e800: ================================================================
# 0002ec00: ================================================================
# 0002f000: ================================================================
# 0002f400: ================================================================
# 0002f800: ================================================================
# 0002fc00: ================================================================
# 00030000: ================================================================
# 00030400: ================================================================
# 00030800: ================================================================
# 00030c00: ================================================================
# 00031000: ================================================================
# 00031400: =====================================..h=.......................
#        (2 lines all free)
# 00032000: ................................................
# Stack used:  0x0254 of Total: 0x1f00  pct free: 92.5%
# Memory used: 0x001_91a0 of Total: 0x003_2300  free: 0x001_9160 pct free: 50.0%
# 1-Blocks:          39  2-Blocks:         13
# Max Block size:  6145  Max Free size:  6147
# h=MLhhhh=DhhhhhDBBBBhDhBh===.DBDB=BBBh=====BBB.B=B.B=BBB.B=.B.B= Bh===.B=h===========B=....h============h========h=============== ===h============================================================ ===h============================================================
# ===h=.......h=..h=...h===.............h=======..S........hh..... .....................B..h========............................... ....................................h=========================== ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ =====================================..h=....................... ................................................

# %%
# and show the difference between the last two snapshots
map_4 - map_3
# Out:
#  -->
# Stack used:  0x0254 of Total: 0x1f00  pct free: 92.5%
# Memory used: 0x001_91a0 of Total: 0x003_2300  free: 0x001_9160 pct free: 50.0%
# 1-Blocks:          39  2-Blocks:         13
# Max Block size:  6145  Max Free size:  6147
# h=MLhhhh=DhhhhhDBBBBhDhBh===.DBDB=BBBh=====BBB.B=B.B=BBB.B=.B.B= Bh===.B=h===========B=....h============h========h=============== ===h============================================================ ===h============================================================
# ===h=.......h=..h=...h===.............h=======..S........hh..... .....................B..h========............................... ....................................h=========================== ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ =====================================..h=....................... ................................................

# %%
# or the reverse to see what got freed ( on RED)
map_3 - map_4
# Out:
#  -->
# Stack used:  0x0254 of Total: 0x1f00  pct free: 92.5%
# Memory used: 0x003_1540 of Total: 0x003_2300  free: 0x000_0dc0 pct free: 1.7%
# 1-Blocks:          67  2-Blocks:         16
# Max Block size:  6145  Max Free size:   203
# h=MLhhhh=DhhhhhDBBBBhDhBh===hDBDB=BBBh=====BBBBB=BhB=BBBhB=hBSB= Bh===SB=h===========B=h=SSh============h========h=============== ===h============================================================ ===h============================================================
# ===h=SSSh=hhhhhh=SSh=h===h===h======SSh=======SSSShThhhBB...h=== =h=====h============..h=h========h========================h====. ...........h=h================================================h= ================================================================
# ===============================h================================ ================================================================ ================================================================ ================================h===============================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ =================================h============================== ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ==================================h============================= ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ===================================h============================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ====================================h=========================== ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ =====================================........................... ................................................

# %%
# are we back to where we started?
map_4 - map_1
# Out:
#  -->
# Stack used:  0x0254 of Total: 0x1f00  pct free: 92.5%
# Memory used: 0x001_91a0 of Total: 0x003_2300  free: 0x001_9160 pct free: 50.0%
# 1-Blocks:          39  2-Blocks:         13
# Max Block size:  6145  Max Free size:  6147
# h=MLhhhh=DhhhhhDBBBBhDhBh===.DBDB=BBBh=====BBB.B=B.B=BBB.B=.B.B= Bh===.B=h===========B=....h============h========h=============== ===h============================================================ ===h============================================================
# ===h=.......h=..h=...h===.............h=======..S........hh..... .....................B..h========............................... ....................................h=========================== ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ =====================================..h=....................... ................................................

# %%
# %mpy print(dir())
# Out:
# ['machine', 'gc', '__name__', 'micropython', 'foo', 'rp2', '_']
# ["['machine', 'gc', '__name__', 'micropython', 'foo', 'rp2', '_']"]

# %%
# %mpy del foo, f, w
# %mpy import gc; gc.collect()

# take another memory snapshot 
mem_lst = %mpy import micropython; micropython.mem_info(True)
map_5=MemoryInfo(mem_lst )

map_5-map_1
# Out:
# stack: 596 out of 7936
# GC: total: 205568, used: 102816, free: 102752
#  No. of 1-blocks: 39, 2-blocks: 13, max blk sz: 6145, max free sz: 6147
# GC memory layout; from 2000dd00:
# 00000000: h=MLhhhh=DhhhhhDBBBBhDhBh===.DBDB=BBBh=====BBB.B=B.B=BBB.B=.B.B=
# 00000400: Bh===.B=h===========B=..hhh============h========h===============
# 00000800: ===h============================================================
# 00000c00: ===h============================================================
# 00001000: ===h=.B........h=..h=h===.......h=....h=======..S...............
# 00001400: ........................h========...............................
#        (95 lines all free)
# 00019400: ....................................h===========================
# 00019800: ================================================================
# 00019c00: ================================================================
# 0001a000: ================================================================
# 0001a400: ================================================================
# 0001a800: ================================================================
# 0001ac00: ================================================================
# 0001b000: ================================================================
# 0001b400: ================================================================
# 0001b800: ================================================================
# 0001bc00: ================================================================
# 0001c000: ================================================================
# 0001c400: ================================================================
# 0001c800: ================================================================
# 0001cc00: ================================================================
# 0001d000: ================================================================
# 0001d400: ================================================================
# 0001d800: ================================================================
# 0001dc00: ================================================================
# 0001e000: ================================================================
# 0001e400: ================================================================
# 0001e800: ================================================================
# 0001ec00: ================================================================
# 0001f000: ================================================================
# 0001f400: ================================================================
# 0001f800: ================================================================
# 0001fc00: ================================================================
# 00020000: ================================================================
# 00020400: ================================================================
# 00020800: ================================================================
# 00020c00: ================================================================
# 00021000: ================================================================
# 00021400: ================================================================
# 00021800: ================================================================
# 00021c00: ================================================================
# 00022000: ================================================================
# 00022400: ================================================================
# 00022800: ================================================================
# 00022c00: ================================================================
# 00023000: ================================================================
# 00023400: ================================================================
# 00023800: ================================================================
# 00023c00: ================================================================
# 00024000: ================================================================
# 00024400: ================================================================
# 00024800: ================================================================
# 00024c00: ================================================================
# 00025000: ================================================================
# 00025400: ================================================================
# 00025800: ================================================================
# 00025c00: ================================================================
# 00026000: ================================================================
# 00026400: ================================================================
# 00026800: ================================================================
# 00026c00: ================================================================
# 00027000: ================================================================
# 00027400: ================================================================
# 00027800: ================================================================
# 00027c00: ================================================================
# 00028000: ================================================================
# 00028400: ================================================================
# 00028800: ================================================================
# 00028c00: ================================================================
# 00029000: ================================================================
# 00029400: ================================================================
# 00029800: ================================================================
# 00029c00: ================================================================
# 0002a000: ================================================================
# 0002a400: ================================================================
# 0002a800: ================================================================
# 0002ac00: ================================================================
# 0002b000: ================================================================
# 0002b400: ================================================================
# 0002b800: ================================================================
# 0002bc00: ================================================================
# 0002c000: ================================================================
# 0002c400: ================================================================
# 0002c800: ================================================================
# 0002cc00: ================================================================
# 0002d000: ================================================================
# 0002d400: ================================================================
# 0002d800: ================================================================
# 0002dc00: ================================================================
# 0002e000: ================================================================
# 0002e400: ================================================================
# 0002e800: ================================================================
# 0002ec00: ================================================================
# 0002f000: ================================================================
# 0002f400: ================================================================
# 0002f800: ================================================================
# 0002fc00: ================================================================
# 00030000: ================================================================
# 00030400: ================================================================
# 00030800: ================================================================
# 00030c00: ================================================================
# 00031000: ================================================================
# 00031400: =====================================...........................
#        (2 lines all free)
# 00032000: ................................................
#  -->
# Stack used:  0x0254 of Total: 0x1f00  pct free: 92.5%
# Memory used: 0x001_91a0 of Total: 0x003_2300  free: 0x001_9160 pct free: 50.0%
# 1-Blocks:          39  2-Blocks:         13
# Max Block size:  6145  Max Free size:  6147
# h=MLhhhh=DhhhhhDBBBBhDhBh===.DBDB=BBBh=====BBB.B=B.B=BBB.B=.B.B= Bh===.B=h===========B=..hhh============h========h=============== ===h============================================================ ===h============================================================
# ===h=.B........h=..h=h===.......h=....h=======..S............... ........................h========............................... ....................................h=========================== ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ =====================================........................... ................................................

# %%
map_5 - map_4
# Out:
#  -->
# Stack used:  0x0254 of Total: 0x1f00  pct free: 92.5%
# Memory used: 0x001_91a0 of Total: 0x003_2300  free: 0x001_9160 pct free: 50.0%
# 1-Blocks:          39  2-Blocks:         13
# Max Block size:  6145  Max Free size:  6147
# h=MLhhhh=DhhhhhDBBBBhDhBh===.DBDB=BBBh=====BBB.B=B.B=BBB.B=.B.B= Bh===.B=h===========B=..hhh============h========h=============== ===h============================================================ ===h============================================================
# ===h=.B........h=..h=h===.......h=....h=======..S............... ........................h========............................... ....................................h=========================== ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ =====================================........................... ................................................

# %%
map_5
# Out:
#  -->
# Stack used:  0x0254 of Total: 0x1f00  pct free: 92.5%
# Memory used: 0x001_91a0 of Total: 0x003_2300  free: 0x001_9160 pct free: 50.0%
# 1-Blocks:          39  2-Blocks:         13
# Max Block size:  6145  Max Free size:  6147
# h=MLhhhh=DhhhhhDBBBBhDhBh===.DBDB=BBBh=====BBB.B=B.B=BBB.B=.B.B= Bh===.B=h===========B=..hhh============h========h=============== ===h============================================================ ===h============================================================
# ===h=.B........h=..h=h===.......h=....h=======..S............... ........................h========............................... ....................................h=========================== ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ =====================================........................... ................................................
