# %% [markdown]
# ## MicroPython memory map visualizer
#
# The below class is used to visualize the memory map of MicroPython. It is based on the `micropython.memory_info(1)` output.
# It can be used to visualize the current usage of the memory before and after gc collection, or to visualize the difference between two memory maps.

# %%
from micropython_magic.memoryinfo import MemoryInfo

# %%
# issue soft reset before running
# %mpy --soft-reset
mem_lst = %mpy import micropython; micropython.mem_info(True)
mem_lst
# Out:
# True
# stack: 720 out of 15360
# GC: total: 56000, used: 1184, free: 54816, max new split: 110592
#  No. of 1-blocks: 22, 2-blocks: 7, max blk sz: 19, max free sz: 3416
# GC memory layout; from 3ffcf6f0:
# 00000000: h=TLhhhBM..Dh=hh=hhh==================hh=======h=======h=hhBhhhh
# 00000400: B..h..h..h=h==..h=h=............................................
#        (52 lines all free)
# 0000d800: ............................................
# ['stack: 720 out of 15360',
#  'GC: total: 56000, used: 1184, free: 54816, max new split: 110592',
#  ' No. of 1-blocks: 22, 2-blocks: 7, max blk sz: 19, max free sz: 3416',
#  'GC memory layout; from 3ffcf6f0:',
#  '00000000: h=TLhhhBM..Dh=hh=hhh==================hh=======h=======h=hhBhhhh',
#  '00000400: B..h..h..h=h==..h=h=............................................',
#  '       (52 lines all free)',
#  '0000d800: ............................................']

# %%
# create the memory map using the output, and display it
# map_1 = MemoryInfo(mem_lst.data, columns=1)
map_1 = MemoryInfo(mem_lst, cols=1)
map_1
# Out:
# Stack used:  0x02d0 of Total: 0x3c00  pct free: 95.3%
# Memory used: 0x000_04a0 of Total: 0x000_dac0  free: 0x000_d620 pct free: 97.9%
# 1-Blocks:          22  2-Blocks:          7
# Max Block size:    19  Max Free size:  3416
# h=TLhhhBM..Dh=hh=hhh==================hh=======h=======h=hhBhhhh
# B..h..h..h=h==..h=h=............................................
# ............................................

# %%
# default = 4 columns
map_1.columns = 2
map_1
# Out:
# Stack used:  0x02d0 of Total: 0x3c00  pct free: 95.3%
# Memory used: 0x000_04a0 of Total: 0x000_dac0  free: 0x000_d620 pct free: 97.9%
# 1-Blocks:          22  2-Blocks:          7
# Max Block size:    19  Max Free size:  3416
# h=TLhhhBM..Dh=hh=hhh==================hh=======h=======h=hhBhhhh B..h..h..h=h==..h=h=............................................
# ............................................

# %%
map_1.rainbow = True  # alternating colors for each block
map_1
# Out:
# Stack used:  0x02d0 of Total: 0x3c00  pct free: 95.3%
# Memory used: 0x000_04a0 of Total: 0x000_dac0  free: 0x000_d620 pct free: 97.9%
# 1-Blocks:          22  2-Blocks:          7
# Max Block size:    19  Max Free size:  3416
# h=TLhhhBM..Dh=hh=hhh==================hh=======h=======h=hhBhhhh B..h..h..h=h==..h=h=............................................
# ............................................

# %%
# consume some more memory
# %mpy print(help('modules'))
# %mpy import gc; gc.collect()

mem_lst = %mpy import micropython; micropython.mem_info(True)
map_2=MemoryInfo(mem_lst, cols=2 )
map_2.rainbow = True
map_2
# Out:
# __main__          btree             io                ssl
# _asyncio          builtins          json              struct
# _boot             cmath             machine           sys
# _espnow           collections       machine           time
# _onewire          cryptolib         math              tls
# _thread           deflate           micropython       uasyncio
# _webrepl          dht               mip/__init__      uctypes
# aioespnow         ds18x20           neopixel          umqtt/robust
# apa106            errno             network           umqtt/simple
# array             esp               ntptime           upysh
# asyncio/__init__  esp32             onewire           urequests
# asyncio/core      espnow            os                vfs
# asyncio/event     flashbdev         platform          webrepl
# asyncio/funcs     framebuf          random            webrepl_setup
# asyncio/lock      gc                re                websocket
# asyncio/stream    hashlib           requests/__init__
# binascii          heapq             select
# bluetooth         inisetup          socket
# Plus any modules on the filesystem
# None
# stack: 720 out of 15360
# GC: total: 56000, used: 1104, free: 54896, max new split: 110592
#  No. of 1-blocks: 17, 2-blocks: 7, max blk sz: 19, max free sz: 3321
# GC memory layout; from 3ffcf6f0:
# 00000000: h=hLhhh=MhhDB..h=hhh==================hh=======h=======h=h......
# 00000400: ..h=..h=...h==.......................hh.B..h....................
# 00000800: .................................................h=.............
#        (51 lines all free)
# 0000d800: ............................................
# Stack used:  0x02d0 of Total: 0x3c00  pct free: 95.3%
# Memory used: 0x000_0450 of Total: 0x000_dac0  free: 0x000_d670 pct free: 98.0%
# 1-Blocks:          17  2-Blocks:          7
# Max Block size:    19  Max Free size:  3321
# h=hLhhh=MhhDB..h=hhh==================hh=======h=======h=h...... ..h=..h=...h==.......................hh.B..h....................
# .................................................h=............. ............................................

# %%
# %%micropython
# eat even more memory - with disabled gc
import gc

gc.disable()
foo = "Parrot"
try:
    for _ in range(15):
        foo = foo + foo
except MemoryError as e:
    print(e)
    pass
# Out:
# memory allocation failed, allocating 98305 bytes

# %%
# take anoter memory snapshot 
mem_lst = %mpy micropython.mem_info(True)
map_3=MemoryInfo(mem_lst)
map_3
# Out:
# stack: 720 out of 15360
# GC: total: 112000, used: 100656, free: 11344, max new split: 53248
#  No. of 1-blocks: 45, 2-blocks: 10, max blk sz: 3073, max free sz: 427
# GC memory layout; from 3ffcf6f0:
# 00000000: h=hLhhh=MhhDBhBh=hhh==================hh=======h=======h=hhhSShh
# 00000400: =Sh=h=h=h===SShhhhhh===h======SSSSSSShhSBShhh============Th====h
# 00000800: =====h====hBh=======h==========..........h=......h=h============
# 00000c00: ============h================================================h==
# 00001000: ================================================================
# 00001400: ==============================h=================================
# 00001800: ================================================================
# 00001c00: ================================================================
# 00002000: ===============================h================================
# 00002400: ================================================================
# 00002800: ================================================================
# 00002c00: ================================================================
# 00003000: ================================================================
# 00003400: ================================================================
# 00003800: ================================h===============================
# 00003c00: ================================================================
# 00004000: ================================================================
# 00004400: ================================================================
# 00004800: ================================================================
# 00004c00: ================================================================
# 00005000: ================================================================
# 00005400: ================================================================
# 00005800: ================================================================
# 00005c00: ================================================================
# 00006000: ================================================================
# 00006400: ================================================================
# 00006800: =================================h==============================
# 00006c00: ================================================================
# 00007000: ================================================================
# 00007400: ================================================================
# 00007800: ================================================================
# 00007c00: ================================================================
# 00008000: ================================================================
# 00008400: ================================================================
# 00008800: ================================================================
# 00008c00: ================================================================
# 00009000: ================================================================
# 00009400: ================================================================
# 00009800: ================================================================
# 00009c00: ================================================================
# 0000a000: ================================================================
# 0000a400: ================================================================
# 0000a800: ================================================================
# 0000ac00: ================================================================
# 0000b000: ================================================================
# 0000b400: ================================================================
# 0000b800: ================================================================
# 0000bc00: ================================================================
# 0000c000: ================================================================
# 0000c400: ================================================================
# 0000c800: ==================================..............................
#        (3 lines all free)
# 0000d800: ............................................
# GC memory layout; from 3ffe4c00:
# 00000000: h===============================================================
# 00000400: ================================================================
# 00000800: ================================================================
# 00000c00: ================================================================
# 00001000: ================================================================
# 00001400: ================================================================
# 00001800: ================================================================
# 00001c00: ================================================================
# 00002000: ================================================================
# 00002400: ================================================================
# 00002800: ================================================================
# 00002c00: ================================================================
# 00003000: ================================================================
# 00003400: ================================================================
# 00003800: ================================================================
# 00003c00: ================================================================
# 00004000: ================================================================
# 00004400: ================================================================
# 00004800: ================================================================
# 00004c00: ================================================================
# 00005000: ================================================================
# 00005400: ================================================================
# 00005800: ================================================================
# 00005c00: ================================================================
# 00006000: ================================================================
# 00006400: ================================================================
# 00006800: ================================================================
# 00006c00: ================================================================
# 00007000: ================================================================
# 00007400: ================================================================
# 00007800: ================================================================
# 00007c00: ================================================================
# 00008000: ================================================================
# 00008400: ================================================================
# 00008800: ================================================================
# 00008c00: ================================================================
# 00009000: ================================================================
# 00009400: ================================================================
# 00009800: ================================================================
# 00009c00: ================================================================
# 0000a000: ================================================================
# 0000a400: ================================================================
# 0000a800: ================================================================
# 0000ac00: ================================================================
# 0000b000: ================================================================
# 0000b400: ================================================================
# 0000b800: ================================================================
# 0000bc00: ================================================================
# 0000c000: =...............................................................
#        (5 lines all free)
# 0000d800: ............................................
# Stack used:  0x02d0 of Total: 0x3c00  pct free: 95.3%
# Memory used: 0x001_8930 of Total: 0x001_b580  free: 0x000_2c50 pct free: 10.1%
# 1-Blocks:          45  2-Blocks:         10
# Max Block size:  3073  Max Free size:   427
# h=hLhhh=MhhDBhBh=hhh==================hh=======h=======h=hhhSShh =Sh=h=h=h===SShhhhhh===h======SSSSSSShhSBShhh============Th====h =====h====hBh=======h==========..........h=......h=h============ ============h================================================h==
# ================================================================ ==============================h================================= ================================================================ ================================================================
# ===============================h================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================h=============================== ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ =================================h============================== ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ==================================.............................. ............................................h===================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ =============================================...................
# ................................................................ ........................

# %%
map_3.rainbow = True
map_3
# Out:
# Stack used:  0x02d0 of Total: 0x3c00  pct free: 95.3%
# Memory used: 0x001_8930 of Total: 0x001_b580  free: 0x000_2c50 pct free: 10.1%
# 1-Blocks:          45  2-Blocks:         10
# Max Block size:  3073  Max Free size:   427
# h=hLhhh=MhhDBhBh=hhh==================hh=======h=======h=hhhSShh =Sh=h=h=h===SShhhhhh===h======SSSSSSShhSBShhh============Th====h =====h====hBh=======h==========..........h=......h=h============ ============h================================================h==
# ================================================================ ==============================h================================= ================================================================ ================================================================
# ===============================h================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================h=============================== ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ =================================h============================== ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ==================================.............................. ............................................h===================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ =============================================...................
# ................................................................ ........................

# %%
# compare snapshot 1 and 2 to see
#  - what remained the same = Black on Blue
#  - what was freed up = Green on Green ( can also be due to additional pages being reported)
#  - what was allocated = Yellow or White on Red

map_3 - map_1
# Out:
#  -->
# Stack used:  0x02d0 of Total: 0x3c00  pct free: 95.3%
# Memory used: 0x001_8930 of Total: 0x001_b580  free: 0x000_2c50 pct free: 10.1%
# 1-Blocks:          45  2-Blocks:         10
# Max Block size:  3073  Max Free size:   427
# h=hLhhh=MhhDBhBh=hhh==================hh=======h=======h=hhhSShh =Sh=h=h=h===SShhhhhh===h======SSSSSSShhSBShhh============Th====h =====h====hBh=======h==========..........h=......h=h============ ============h================================================h==
# ================================================================ ==============================h================================= ================================================================ ================================================================
# ===============================h================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================h=============================== ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ =================================h============================== ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ==================================.............................. ............................................h===================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ =============================================...................
# ................................................................ ........................

# %%
# now free up some memory and take another memory snapshot 
# %mpy import gc; gc.collect()
mem_lst = %mpy import micropython; micropython.mem_info(True)
map_4=MemoryInfo(mem_lst )
map_4.rainbow = True
map_4.show_free = True
map_4
# Out:
# stack: 720 out of 15360
# GC: total: 112000, used: 50608, free: 61392, max new split: 53248
#  No. of 1-blocks: 18, 2-blocks: 7, max blk sz: 3073, max free sz: 3072
# GC memory layout; from 3ffcf6f0:
# 00000000: h=hLhhh=MhhDB..h=hhh==================hh=======h=======h=h......
# 00000400: ..h=..h=...........h===................S........................
# 00000800: ............h=======h==========hh.B..h..........................
#        (47 lines all free)
# 0000c800: ......................................h=........................
#        (3 lines all free)
# 0000d800: ............................................
# GC memory layout; from 3ffe4c00:
# 00000000: h===============================================================
# 00000400: ================================================================
# 00000800: ================================================================
# 00000c00: ================================================================
# 00001000: ================================================================
# 00001400: ================================================================
# 00001800: ================================================================
# 00001c00: ================================================================
# 00002000: ================================================================
# 00002400: ================================================================
# 00002800: ================================================================
# 00002c00: ================================================================
# 00003000: ================================================================
# 00003400: ================================================================
# 00003800: ================================================================
# 00003c00: ================================================================
# 00004000: ================================================================
# 00004400: ================================================================
# 00004800: ================================================================
# 00004c00: ================================================================
# 00005000: ================================================================
# 00005400: ================================================================
# 00005800: ================================================================
# 00005c00: ================================================================
# 00006000: ================================================================
# 00006400: ================================================================
# 00006800: ================================================================
# 00006c00: ================================================================
# 00007000: ================================================================
# 00007400: ================================================================
# 00007800: ================================================================
# 00007c00: ================================================================
# 00008000: ================================================================
# 00008400: ================================================================
# 00008800: ================================================================
# 00008c00: ================================================================
# 00009000: ================================================================
# 00009400: ================================================================
# 00009800: ================================================================
# 00009c00: ================================================================
# 0000a000: ================================================================
# 0000a400: ================================================================
# 0000a800: ================================================================
# 0000ac00: ================================================================
# 0000b000: ================================================================
# 0000b400: ================================================================
# 0000b800: ================================================================
# 0000bc00: ================================================================
# 0000c000: =...............................................................
#        (5 lines all free)
# 0000d800: ............................................
# Stack used:  0x02d0 of Total: 0x3c00  pct free: 95.3%
# Memory used: 0x000_c5b0 of Total: 0x001_b580  free: 0x000_efd0 pct free: 54.8%
# 1-Blocks:          18  2-Blocks:          7
# Max Block size:  3073  Max Free size:  3072
# h=hLhhh=MhhDB..h=hhh==================hh=======h=======h=h...... ..h=..h=...........h===................S........................ ............h=======h==========hh.B..h.......................... ......................................h=........................
# ............................................h=================== ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# =============================================................... ................................................................ ........................

# %%
# and show the difference between the last two snapshots
map_4 - map_3
# Out:
#  -->
# Stack used:  0x02d0 of Total: 0x3c00  pct free: 95.3%
# Memory used: 0x000_c5b0 of Total: 0x001_b580  free: 0x000_efd0 pct free: 54.8%
# 1-Blocks:          18  2-Blocks:          7
# Max Block size:  3073  Max Free size:  3072
# h=hLhhh=MhhDB..h=hhh==================hh=======h=======h=h...... ..h=..h=...........h===................S........................ ............h=======h==========hh.B..h.......................... ......................................h=........................
# ............................................h=================== ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# =============================================................... ................................................................ ........................

# %%
# or the reverse to see what got freed ( on RED)
map_3 - map_4
# Out:
#  -->
# Stack used:  0x02d0 of Total: 0x3c00  pct free: 95.3%
# Memory used: 0x001_8930 of Total: 0x001_b580  free: 0x000_2c50 pct free: 10.1%
# 1-Blocks:          45  2-Blocks:         10
# Max Block size:  3073  Max Free size:   427
# h=hLhhh=MhhDBhBh=hhh==================hh=======h=======h=hhhSShh =Sh=h=h=h===SShhhhhh===h======SSSSSSShhSBShhh============Th====h =====h====hBh=======h==========..........h=......h=h============ ============h================================================h==
# ================================================================ ==============================h================================= ================================================================ ================================================================
# ===============================h================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================h=============================== ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ =================================h============================== ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ==================================.............................. ............................................h===================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ =============================================...................
# ................................................................ ........................

# %%
# are we back to where we started?
map_4 - map_1
# Out:
#  -->
# Stack used:  0x02d0 of Total: 0x3c00  pct free: 95.3%
# Memory used: 0x000_c5b0 of Total: 0x001_b580  free: 0x000_efd0 pct free: 54.8%
# 1-Blocks:          18  2-Blocks:          7
# Max Block size:  3073  Max Free size:  3072
# h=hLhhh=MhhDB..h=hhh==================hh=======h=======h=h...... ..h=..h=...........h===................S........................ ............h=======h==========hh.B..h.......................... ......................................h=........................
# ............................................h=================== ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# =============================================................... ................................................................ ........................

# %%
# %mpy print(dir())
# Out:
# ['bdev', 'gc', '__name__', 'micropython', 'foo', '_', 'vfs']
# ["['bdev', 'gc', '__name__', 'micropython', 'foo', '_', 'vfs']"]

# %%
# %mpy del foo, f, w
# %mpy import gc; gc.collect()

# take another memory snapshot 
mem_lst = %mpy import micropython; micropython.mem_info(True)
map_5=MemoryInfo(mem_lst )

map_5-map_1
# Out:
# stack: 720 out of 15360
# GC: total: 112000, used: 50608, free: 61392, max new split: 53248
#  No. of 1-blocks: 18, 2-blocks: 7, max blk sz: 3073, max free sz: 3341
# GC memory layout; from 3ffcf6f0:
# 00000000: h=hLhhh=MhhDB..h=hhh==================hh=======h=======h=h...h..
# 00000400: ....hh=.B..hh=.....h===.......h=.......S........................
# 00000800: ............h=======h==========.................................
#        (51 lines all free)
# 0000d800: ............................................
# GC memory layout; from 3ffe4c00:
# 00000000: h===============================================================
# 00000400: ================================================================
# 00000800: ================================================================
# 00000c00: ================================================================
# 00001000: ================================================================
# 00001400: ================================================================
# 00001800: ================================================================
# 00001c00: ================================================================
# 00002000: ================================================================
# 00002400: ================================================================
# 00002800: ================================================================
# 00002c00: ================================================================
# 00003000: ================================================================
# 00003400: ================================================================
# 00003800: ================================================================
# 00003c00: ================================================================
# 00004000: ================================================================
# 00004400: ================================================================
# 00004800: ================================================================
# 00004c00: ================================================================
# 00005000: ================================================================
# 00005400: ================================================================
# 00005800: ================================================================
# 00005c00: ================================================================
# 00006000: ================================================================
# 00006400: ================================================================
# 00006800: ================================================================
# 00006c00: ================================================================
# 00007000: ================================================================
# 00007400: ================================================================
# 00007800: ================================================================
# 00007c00: ================================================================
# 00008000: ================================================================
# 00008400: ================================================================
# 00008800: ================================================================
# 00008c00: ================================================================
# 00009000: ================================================================
# 00009400: ================================================================
# 00009800: ================================================================
# 00009c00: ================================================================
# 0000a000: ================================================================
# 0000a400: ================================================================
# 0000a800: ================================================================
# 0000ac00: ================================================================
# 0000b000: ================================================================
# 0000b400: ================================================================
# 0000b800: ================================================================
# 0000bc00: ================================================================
# 0000c000: =...............................................................
#        (5 lines all free)
# 0000d800: ............................................
#  -->
# Stack used:  0x02d0 of Total: 0x3c00  pct free: 95.3%
# Memory used: 0x000_c5b0 of Total: 0x001_b580  free: 0x000_efd0 pct free: 54.8%
# 1-Blocks:          18  2-Blocks:          7
# Max Block size:  3073  Max Free size:  3341
# h=hLhhh=MhhDB..h=hhh==================hh=======h=======h=h...h.. ....hh=.B..hh=.....h===.......h=.......S........................ ............h=======h==========................................. ............................................h===================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ =============================================...................
# ................................................................ ........................

# %%
map_5 - map_4
# Out:
#  -->
# Stack used:  0x02d0 of Total: 0x3c00  pct free: 95.3%
# Memory used: 0x000_c5b0 of Total: 0x001_b580  free: 0x000_efd0 pct free: 54.8%
# 1-Blocks:          18  2-Blocks:          7
# Max Block size:  3073  Max Free size:  3341
# h=hLhhh=MhhDB..h=hhh==================hh=======h=======h=h...h.. ....hh=.B..hh=.....h===.......h=.......S........................ ............h=======h==========................................. ............................................h===================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ =============================================...................
# ................................................................ ........................

# %%
map_5
# Out:
#  -->
# Stack used:  0x02d0 of Total: 0x3c00  pct free: 95.3%
# Memory used: 0x000_c5b0 of Total: 0x001_b580  free: 0x000_efd0 pct free: 54.8%
# 1-Blocks:          18  2-Blocks:          7
# Max Block size:  3073  Max Free size:  3341
# h=hLhhh=MhhDB..h=hhh==================hh=======h=======h=h...h.. ....hh=.B..hh=.....h===.......h=.......S........................ ............h=======h==========................................. ............................................h===================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ ================================================================
# ================================================================ ================================================================ ================================================================ =============================================...................
# ................................................................ ........................
