# %%
# !mpremote cp ../../micropython-stubber/src/stubber/board/logging.py :logging.py
# !mpremote cp ../../micropython-stubber/src/stubber/board/createstubs_info.py :createstubs.py

# %%
# %mpy --reset
# !mpremote ls

# %%
# %mpy import createstubs

# %%
output = _
# log_text = __
log_text = list(output.data)

# %%
# %store log_text

# %%
# %store -r log_text

# %%
from micropython_magic.memoryinfo import MemoryInfoList, MemoryInfo

# %%
mil = MemoryInfoList(show_free=False, columns=2)
mil.parse_log(log_text)
mil
# Out:
# zlib
# Stack used:  0x0884 of Total: 0x1f00  pct free: 72.5%
# Memory used: 0x000_c690 of Total: 0x002_ee40  free: 0x002_27b0 pct free: 73.5%
# 1-Blocks:         525  2-Blocks:         96
# Max Block size:   122  Max Free size:  4156
# MDMhhLhDShhSSSDSDBhhh===BSB=Dh====B=BBBBBBSB=B.B=BBBLB=LBMB=Bh== =DB=h===========h===================BBBh==h=h=====h=============
# ====h=========================================================== ====h===========================================================
# ====h=h=h====h=..hh===S..DST=ShMD..ShhSBMDh=Shh===h==ShhDBhBMDhM DShhh=======h========h======Sh..Sh===.h====.SLDh.h====h===Sh====
# ===.Dh.Dh=========SSh=S.h============SSSh==hDBBhhSSBhDS.BDBBBh== BBBBBB=DBBBSSBBBB=Sh==Sh===SLDBBh=h========BBBBBBBBBBSBh=======S
# h=======BDBSB=BBBBBh==h===========B=BB=Bh================h.B=h== =SBB=BBBh===BBB=hSSh===h========h===ShhhhB=.h==Shh===DBSLBhSh===
# h=h=======BBBh=h==============h=====BBBhSh=....Shh===B.B=Sh===== ==BBShh============hh=h=======h===SShShh=======SShShShh=======SS
# h=Sh=h====Shh=ShSDSh======MD.Dh=======Sh=.B..SS.SS.SSSh====S..S. .Sh=h======....h=======h======h====S.SSSSS....SS....SS..hh=.S.hh
# ..hh...hhhhhSShhhh...hSSS..h...SShh..Sh=...hhh======.....h====== =Sh=======Sh=======.S.....h==h=h===h=h=h=....h====h=h=Sh==h=h=h=
# h======h=======..SShh=======.....h=h========....Sh==h========h== ====SSh==SS..S..S....h=======h==================================
# =====h....Sh....Shh============================================= =========.h===============================h========.....S.....Sh
# =====.Sh=h======.SSh=.....Sh======.h===h=======h=======Sh=h===== ==.......SSh==h========...S.Sh=======.h=h======h====..Sh=h======
# ======S.....Sh======h======..SSh======...Sh=h=======....SSSh==== ====Sh=======h=======......h=h========...Shh========SShh========
# h========.......SSh=SS.....SS....Sh======....h=h======.SShShShSh =ShShSh=h======.Sh===h.....h=======....h==h=======.SSh======..Sh
# .......SSSh==h======..Sh==h========.....S.......SSh=.hS....h==== ==....h=SSh=======.h=======h======Sh======.....h=======Sh=Sh====
# ==..h======h=======..Sh=h=======..Sh=h======...Sh....h=======... h========h=======...h=======.....h========h======.Sh==......S..S
# h========..h===============================.Sh.h=======....Sh=== SS..h======h=======.....Shh======....h=======h==============h===
# ====h=======Sh=.....h======..Sh=.....h======h======.h=======h=== ====.h=======h====MD...h=DBB....Shh=======MD...h.DBD.B=hBh======
# =h=======.....h========h=======......h=======...Sh=h======h===== ==h=======S....Sh======h======h======h===========Sh=======.h====
# ===================================================h=h======h=== ===h======h======...Shh======h======h======h=======h======S.....
# ..........h======...............h======.....................h=== ====.......T...................h=======.........T=T=ShShT=......
# ..........Shh======h======h======............h======..h========= ====================================================h=======....
# ...........................hh=================================== ================================================================
# ======================.....Sh===...............................T h=======..................h=======..............................
# ...Sh........SSh=ShShSh........ShSh=Sh=Sh=ShSh=Sh=ShSh=Sh=...... ..Sh=ShShShh=======hShShSh=Sh=S........Sh=======hShShSh........S
# hShShShh=======ShShShShSh=======ShShSh=Sh=Sh=h=======Sh=h======= .........h=........h=...hSh.....h=hhh...........................
# .....h..............h.....h.....h....h=......................... ................................................................
# ................h======..................h==.................... ................................................................
# ............h.......h==..........h======================h==h==== =h=========h=======================h============================
# ======================h==h==========h=============h=======h==h== h=======........................................................
# ..................................h======================h===h== ======h==========h===h==========================================
# ============h=====h=====h==h=====h===h========================== ===================h==h=========================................
# .....................................................h========== ================================================================
# =====........................................................... .......................................h=======.................
# ..............................h=======.......................... .....................................M..........................
# ..................................hhBhh.B..h=DhDD.Bhh=h===h===h= ...........DDBBBhBh==h===h===BBBhB...h===h====h=================
# =...h===h===.h==================hh.hhhBhh=h===Dhh.h=.h========hh B.h=h===h===h====...............................................
# ....................................

# %%
mil.columns = 1
mil
# Out:
# zlib
# Stack used:  0x0884 of Total: 0x1f00  pct free: 72.5%
# Memory used: 0x000_c690 of Total: 0x002_ee40  free: 0x002_27b0 pct free: 73.5%
# 1-Blocks:         525  2-Blocks:         96
# Max Block size:   122  Max Free size:  4156
# MDMhhLhDShhSSSDSDBhhh===BSB=Dh====B=BBBBBBSB=B.B=BBBLB=LBMB=Bh==
# =DB=h===========h===================BBBh==h=h=====h=============
# ====h===========================================================
# ====h===========================================================
# ====h=h=h====h=..hh===S..DST=ShMD..ShhSBMDh=Shh===h==ShhDBhBMDhM
# DShhh=======h========h======Sh..Sh===.h====.SLDh.h====h===Sh====
# ===.Dh.Dh=========SSh=S.h============SSSh==hDBBhhSSBhDS.BDBBBh==
# BBBBBB=DBBBSSBBBB=Sh==Sh===SLDBBh=h========BBBBBBBBBBSBh=======S
# h=======BDBSB=BBBBBh==h===========B=BB=Bh================h.B=h==
# =SBB=BBBh===BBB=hSSh===h========h===ShhhhB=.h==Shh===DBSLBhSh===
# h=h=======BBBh=h==============h=====BBBhSh=....Shh===B.B=Sh=====
# ==BBShh============hh=h=======h===SShShh=======SShShShh=======SS
# h=Sh=h====Shh=ShSDSh======MD.Dh=======Sh=.B..SS.SS.SSSh====S..S.
# .Sh=h======....h=======h======h====S.SSSSS....SS....SS..hh=.S.hh
# ..hh...hhhhhSShhhh...hSSS..h...SShh..Sh=...hhh======.....h======
# =Sh=======Sh=======.S.....h==h=h===h=h=h=....h====h=h=Sh==h=h=h=
# h======h=======..SShh=======.....h=h========....Sh==h========h==
# ====SSh==SS..S..S....h=======h==================================
# =====h....Sh....Shh=============================================
# =========.h===============================h========.....S.....Sh
# =====.Sh=h======.SSh=.....Sh======.h===h=======h=======Sh=h=====
# ==.......SSh==h========...S.Sh=======.h=h======h====..Sh=h======
# ======S.....Sh======h======..SSh======...Sh=h=======....SSSh====
# ====Sh=======h=======......h=h========...Shh========SShh========
# h========.......SSh=SS.....SS....Sh======....h=h======.SShShShSh
# =ShShSh=h======.Sh===h.....h=======....h==h=======.SSh======..Sh
# .......SSSh==h======..Sh==h========.....S.......SSh=.hS....h====
# ==....h=SSh=======.h=======h======Sh======.....h=======Sh=Sh====
# ==..h======h=======..Sh=h=======..Sh=h======...Sh....h=======...
# h========h=======...h=======.....h========h======.Sh==......S..S
# h========..h===============================.Sh.h=======....Sh===
# SS..h======h=======.....Shh======....h=======h==============h===
# ====h=======Sh=.....h======..Sh=.....h======h======.h=======h===
# ====.h=======h====MD...h=DBB....Shh=======MD...h.DBD.B=hBh======
# =h=======.....h========h=======......h=======...Sh=h======h=====
# ==h=======S....Sh======h======h======h===========Sh=======.h====
# ===================================================h=h======h===
# ===h======h======...Shh======h======h======h=======h======S.....
# ..........h======...............h======.....................h===
# ====.......T...................h=======.........T=T=ShShT=......
# ..........Shh======h======h======............h======..h=========
# ====================================================h=======....
# ...........................hh===================================
# ================================================================
# ======================.....Sh===...............................T
# h=======..................h=======..............................
# ...Sh........SSh=ShShSh........ShSh=Sh=Sh=ShSh=Sh=ShSh=Sh=......
# ..Sh=ShShShh=======hShShSh=Sh=S........Sh=======hShShSh........S
# hShShShh=======ShShShShSh=======ShShSh=Sh=Sh=h=======Sh=h=======
# .........h=........h=...hSh.....h=hhh...........................
# .....h..............h.....h.....h....h=.........................
# ................................................................
# ................h======..................h==....................
# ................................................................
# ............h.......h==..........h======================h==h====
# =h=========h=======================h============================
# ======================h==h==========h=============h=======h==h==
# h=======........................................................
# ..................................h======================h===h==
# ======h==========h===h==========================================
# ============h=====h=====h==h=====h===h==========================
# ===================h==h=========================................
# .....................................................h==========
# ================================================================
# =====...........................................................
# .......................................h=======.................
# ..............................h=======..........................
# .....................................M..........................
# ..................................hhBhh.B..h=DhDD.Bhh=h===h===h=
# ...........DDBBBhBh==h===h===BBBhB...h===h====h=================
# =...h===h===.h==================hh.hhhBhh=h===Dhh.h=.h========hh
# B.h=h===h===h====...............................................
# ....................................

# %%
mil.columns = 7
display(mil, display_id=True)
# Out:
# zlib
# Stack used:  0x0884 of Total: 0x1f00  pct free: 72.5%
# Memory used: 0x000_c690 of Total: 0x002_ee40  free: 0x002_27b0 pct free: 73.5%
# 1-Blocks:         525  2-Blocks:         96
# Max Block size:   122  Max Free size:  4156
# MDMhhLhDShhSSSDSDBhhh===BSB=Dh====B=BBBBBBSB=B.B=BBBLB=LBMB=Bh== =DB=h===========h===================BBBh==h=h=====h============= ====h=========================================================== ====h=========================================================== ====h=h=h====h=..hh===S..DST=ShMD..ShhSBMDh=Shh===h==ShhDBhBMDhM DShhh=======h========h======Sh..Sh===.h====.SLDh.h====h===Sh==== ===.Dh.Dh=========SSh=S.h============SSSh==hDBBhhSSBhDS.BDBBBh==
# BBBBBB=DBBBSSBBBB=Sh==Sh===SLDBBh=h========BBBBBBBBBBSBh=======S h=======BDBSB=BBBBBh==h===========B=BB=Bh================h.B=h== =SBB=BBBh===BBB=hSSh===h========h===ShhhhB=.h==Shh===DBSLBhSh=== h=h=======BBBh=h==============h=====BBBhSh=....Shh===B.B=Sh===== ==BBShh============hh=h=======h===SShShh=======SShShShh=======SS h=Sh=h====Shh=ShSDSh======MD.Dh=======Sh=.B..SS.SS.SSSh====S..S. .Sh=h======....h=======h======h====S.SSSSS....SS....SS..hh=.S.hh
# ..hh...hhhhhSShhhh...hSSS..h...SShh..Sh=...hhh======.....h====== =Sh=======Sh=======.S.....h==h=h===h=h=h=....h====h=h=Sh==h=h=h= h======h=======..SShh=======.....h=h========....Sh==h========h== ====SSh==SS..S..S....h=======h================================== =====h....Sh....Shh============================================= =========.h===============================h========.....S.....Sh =====.Sh=h======.SSh=.....Sh======.h===h=======h=======Sh=h=====
# ==.......SSh==h========...S.Sh=======.h=h======h====..Sh=h====== ======S.....Sh======h======..SSh======...Sh=h=======....SSSh==== ====Sh=======h=======......h=h========...Shh========SShh======== h========.......SSh=SS.....SS....Sh======....h=h======.SShShShSh =ShShSh=h======.Sh===h.....h=======....h==h=======.SSh======..Sh .......SSSh==h======..Sh==h========.....S.......SSh=.hS....h==== ==....h=SSh=======.h=======h======Sh======.....h=======Sh=Sh====
# ==..h======h=======..Sh=h=======..Sh=h======...Sh....h=======... h========h=======...h=======.....h========h======.Sh==......S..S h========..h===============================.Sh.h=======....Sh=== SS..h======h=======.....Shh======....h=======h==============h=== ====h=======Sh=.....h======..Sh=.....h======h======.h=======h=== ====.h=======h====MD...h=DBB....Shh=======MD...h.DBD.B=hBh====== =h=======.....h========h=======......h=======...Sh=h======h=====
# ==h=======S....Sh======h======h======h===========Sh=======.h==== ===================================================h=h======h=== ===h======h======...Shh======h======h======h=======h======S..... ..........h======...............h======.....................h=== ====.......T...................h=======.........T=T=ShShT=...... ..........Shh======h======h======............h======..h========= ====================================================h=======....
# ...........................hh=================================== ================================================================ ======================.....Sh===...............................T h=======..................h=======.............................. ...Sh........SSh=ShShSh........ShSh=Sh=Sh=ShSh=Sh=ShSh=Sh=...... ..Sh=ShShShh=======hShShSh=Sh=S........Sh=======hShShSh........S hShShShh=======ShShShShSh=======ShShSh=Sh=Sh=h=======Sh=h=======
# .........h=........h=...hSh.....h=hhh........................... .....h..............h.....h.....h....h=......................... ................................................................ ................h======..................h==.................... ................................................................ ............h.......h==..........h======================h==h==== =h=========h=======================h============================
# ======================h==h==========h=============h=======h==h== h=======........................................................ ..................................h======================h===h== ======h==========h===h========================================== ============h=====h=====h==h=====h===h========================== ===================h==h=========================................ .....................................................h==========
# ================================================================ =====........................................................... .......................................h=======................. ..............................h=======.......................... .....................................M.......................... ..................................hhBhh.B..h=DhDD.Bhh=h===h===h= ...........DDBBBhBh==h===h===BBBhB...h===h====h=================
# =...h===h===.h==================hh.hhhBhh=h===Dhh.h=.h========hh B.h=h===h===h====............................................... ....................................
# <DisplayHandle display_id=42d0bd4c2023a4477272e513fb0d42bd>

# %%
from IPython.display import display, update_display

mil.colomns = 2
mil.colomns
# did = display(mil, display_id=True)
# update_display(mil, display_id=did.display_id)
# Out:
# 2

# %%
display(mil)

# %%
# display("", display_id="here")
# for mm in mem_info.memory_maps:
#     update_display(mm, display_id="here")

# %%
MemoryInfo?
# Out:
# Init signature:
# MemoryInfo(
#     mmap: 'InitVar[Any]' = '',
#     name: 'str' = '',
#     rainbow: 'bool' = False,
#     total: 'int' = 0,
#     used: 'int' = 0,
#     free: 'int' = 0,
#     one_blocks: 'int' = 0,
#     two_blocks: 'int' = 0,
#     max_block_size: 'int' = 0,
#     max_free_size: 'int' = 0,
#     stack_used: 'int' = 0,
#     stack_total: 'int' = 0,
#     parent: 'MemoryInfoList' = None,
#     show_free: 'bool' = False,
# ) -> None
# Docstring:      MemoryInfo(mmap: 'InitVar[Any]' = '', name: 'str' = '', rainbow: 'bool' = False, total: 'int' = 0, used: 'int' = 0, free: 'int' = 0, one_blocks: 'int' = 0, two_blocks: 'int' = 0, max_block_size: 'int' = 0, max_free_size: 'int' = 0, stack_used: 'int' = 0, stack_total: 'int' = 0, parent: 'MemoryInfoList' = None, show_free: 'bool' = False)
# File:           c:\develop\mypython\micropython-magic\src\micropython_magic\memoryinfo.py
# Type:           type
# Subclasses:

# %%
# import matplotlib.pyplot as plt

# free_mem = [i.free for i in mil]
# max_free = [i.max_free_size for i in mil]
# blocks = [(i.one_blocks, i.two_blocks) for i in mil]

# # plot the free memory with an area chart
# fig, ax1 = plt.subplots()
# c = "green"
# ax1.tick_params(axis='y', labelcolor=c)
# ax1.plot(free_mem, label="free memory", color=c)

# ax2 = ax1.twinx()
# ax2.plot(blocks, label=["1-blocks", "2-blocks]"])

# c = "red"
# ax3 = ax2.twinx()
# ax3.tick_params(axis='y', labelcolor=c)
# ax3.plot(max_free, label="max_free_size", color="red")
# ax3.legend(loc="best")
# plt.show()

# %%
import bqplot.pyplot as plt
import numpy as np


zoom = mil[200:250]
zoom = mil

free_mem = [i.free for i in zoom]
max_free = [i.max_free_size for i in zoom]
blocks1 = [i.one_blocks for i in zoom]
blocks2 = [i.two_blocks for i in zoom]

names = [i.name for i in zoom]

# plot the free memory with an area chart
fig_memory = plt.figure(title="createstubs memory consumption")

# customize axes
axes_1_options = {"x": {"label": "time"}, "y": {"label": "Memory in bytes"}}
# plot the free memory
line_1 = plt.plot(free_mem, labels=["free memory"], display_legend=True, colors=["green"], axes_options=axes_1_options)
# add the log names as labels to the x axis for every 5th entry
label = plt.label(
    text=[x.name for x in zoom][::5],
    x=range(len(zoom))[::5],
    y=[y + 10 for y in free_mem[::5]],
    default_size=14,
    update_on_move=True,
    labels=["name"],
    display_legend=True,
)
label.rotate_angle = -30

# create a sperate scale for the y axis on the right-hand side of the plot to allow for the difference in scale
# plt.scales(scales={"name": "Blocks", "x": plt.Keep})
plt.scales(scales={"x": plt.Keep})
axes_2_options = {
    "x": {"label": "time"},
    "y": {"label": "Blocks", "side": "right", "color": "olive", "label_color": "olive"},
}

line_2 = plt.plot(max_free, labels=["max free"], display_legend=True, axes_options=axes_2_options)


# bar = plt.bar(x= names , y=free_mem, label="free memory", display_legend=True, colors=["green"],axes_options=axes_options,)
# plt.ylim(0, 10_000)
# display(fig_memory, plt.Toolbar(figure=fig_memory))

plt.show(key=None, display_toolbar=True)
# Out:
# VBox(children=(Figure(axes=[Axis(label='time', scale=LinearScale()), Axis(label='Memory in bytes', orientation…

# %%
# use the whole page width for displaying the output in the jupyter notebook web viewer
# not needed for VSCode
from IPython.display import display, HTML

display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("<style>.output_result { max-width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>
# <style>.output_result { max-width:100% !important; }</style>

# %%
mem_info.diff_with = ()
mem_info.data[1:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 mem_info.diff_with = ()
#       2 mem_info.data[1:5]
#
# NameError: name 'mem_info' is not defined

# %%
diff = mem_info[200] - mem_info[1]
diff

# %%
from typing import List


class Bar(list):
    pass
    # def __init__(self, values: List[Info]):
    #     self.values = values

# %%
mem_info.columns = 1
for i in mem_info:
    print(len(i.parent), i.columns, i.parent.columns)

# %%
mem_info

# %%
fig = plt.figure(title="Basic Label Example")
test_line = plt.plot(np.arange(10), y_data[:10])
test_label = plt.label(
    ["Test", "Label", "for", "the", "Data"],
    x=np.arange(5),
    y=y_data[:5],
    default_size=26,
    font_weight="bolder",
    colors=["orange", "red"],
    update_on_move=True,
)
fig
